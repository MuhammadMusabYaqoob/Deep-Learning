# %%
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
# Load your trained model (if not already in memory)
model = tf.keras.models.load_model("models_saved/model.keras")

# %%
# Load the image taken from your mobile
img = cv2.imread("MNIST_digit.png")

# %%
plt.imshow(img)

# %%
# Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (318, 318)

# %%
plt.imshow(gray)

# %%
# Resize to 28x28
resized = cv2.resize(gray, (28, 28))
resized.shape
# Out:
# (28, 28)

# %%
# Normalize the pixel values
resized = resized / 255.0

# %%
# Reshape to match model input shape
reshaped = resized.reshape(1, 28, 28, 1)
reshaped.shape
# Out:
# (1, 28, 28, 1)

# %%
# Predict
prediction = model.predict(reshaped)
print("Probabilities:", prediction)
print("Predicted Class:", prediction.argmax())
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# Probabilities: [[4.8659385e-16 8.3573019e-13 1.2591921e-08 1.0000000e+00 8.2505117e-15
#   4.6278497e-09 9.2214111e-21 4.1603208e-08 4.2491621e-08 4.2368850e-08]]
# Predicted Class: 3
